# %% [markdown]
# <a href="https://colab.research.google.com/github/wallec/FIS02013-Trabalho2/blob/main/Trabalho_2_T%C3%B3picos_de_Astronomia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Wallace da Silva Carvalho
#
# Cartão UFRGS: 156018
#
# Tópicos de Astronomia Galáctica, Extragaláctica e Cosmologia
#
# Trabalho 2 - Determinação de idade, metalicidade, excesso de cor e distância de dois aglomerados globulares fictícios

# %%
import math
import matplotlib.pyplot as plt
import astropy.units as u
from scipy import stats
from astropy.coordinates import SkyCoord

# %% [markdown]
# Diagramas cor-magnitude dos aglomerados (antes dos ajustes)

# %%
infile1 = "/content/Fis2013a.dat"
infile2 = "/content/Fis2013b.dat"

file1 = open(infile1, "r")

als_BV=[]
als_V=[]
bls_BV=[]
bls_V=[]

next(file1)             #Pula a primeira linha do arquivo (cabeçalho)
                        
for linha in file1:
  partes = linha.split()
  als_BV.append(float(partes[7].strip()))
  als_V.append(float(partes[3].strip()))

file1.close()

file2 = open(infile2, "r")

next(file2)             #Pula a primeira linha do arquivo (cabeçalho)
                        
for linha in file2:
  partes = linha.split()
  bls_BV.append(float(partes[7].strip()))
  bls_V.append(float(partes[3].strip()))

file2.close()

# %%
#Fis02013a
plt.scatter(als_BV, als_V, s=1)
plt.gca().invert_yaxis()
plt.title("Fis02013a")
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.show()

# %%
#Fis02013b
plt.scatter(bls_BV, bls_V, s=1)
plt.gca().invert_yaxis()
plt.title("Fis02013b")
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.show()

# %% [markdown]
# Procurando isócronas para Fis02013a

# %%
infile3 = "/content/bvr_008_4750Myr.dat"

file3 = open(infile3, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file3:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file3.close()

# %%
#Comparando com Fis02013a
plt.scatter(als_BV, als_V, s=1, label="Fis02013a")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 4.75Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajustea_BV=[]
ajustea_V=[]

EBV=0.25
mv_Mv=10

for i in range(len(als_BV)):
  ajustea_BV.append(als_BV[i] - EBV)
for i in range(len(als_V)):
  ajustea_V.append(als_V[i] - mv_Mv)

plt.scatter(ajustea_BV, ajustea_V, s=1, label="Fis02013a")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 4.75Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
infile4 = "/content/bvr_008_5000Myr.dat"

file4 = open(infile4, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file4:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file4.close()

# %%
#Comparando com Fis02013a
plt.scatter(als_BV, als_V, s=1, label="Fis02013a")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajustea_BV=[]
ajustea_V=[]

EBV=0.25
mv_Mv=10

for i in range(len(als_BV)):
  ajustea_BV.append(als_BV[i] - EBV)
for i in range(len(als_V)):
  ajustea_V.append(als_V[i] - mv_Mv)

plt.scatter(ajustea_BV, ajustea_V, s=1, label="Fis02013a")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
infile5 = "/content/bvr_008_5500Myr.dat"

file5 = open(infile5, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file5:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file5.close()

# %%
#Comparando com Fis02013a
plt.scatter(als_BV, als_V, s=1, label="Fis02013a")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5.5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajustea_BV=[]
ajustea_V=[]

EBV=0.25
mv_Mv=10

for i in range(len(als_BV)):
  ajustea_BV.append(als_BV[i] - EBV)
for i in range(len(als_V)):
  ajustea_V.append(als_V[i] - mv_Mv)

plt.scatter(ajustea_BV, ajustea_V, s=1, label="Fis02013a")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5.5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %% [markdown]
# Procurando isócronas para Fis02013b

# %%
infile6 = "/content/bvr_008_4500Myr.dat"

file6 = open(infile6, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file6:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file6.close()

# %%
#Comparando com Fis02013b
plt.scatter(bls_BV, bls_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 4.5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajusteb_BV=[]
ajusteb_V=[]

EBV=0.26
mv_Mv=10

for i in range(len(bls_BV)):
  ajusteb_BV.append(bls_BV[i] - EBV)
for i in range(len(bls_V)):
  ajusteb_V.append(bls_V[i] - mv_Mv)

plt.scatter(ajusteb_BV, ajusteb_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 4.5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
infile7 = "/content/bvr_008_4750Myr.dat"

file7 = open(infile7, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file7:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file7.close()

# %%
#Comparando com Fis02013b
plt.scatter(bls_BV, bls_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 4.75Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajusteb_BV=[]
ajusteb_V=[]

EBV=0.26
mv_Mv=10

for i in range(len(bls_BV)):
  ajusteb_BV.append(bls_BV[i] - EBV)
for i in range(len(bls_V)):
  ajusteb_V.append(bls_V[i] - mv_Mv)

plt.scatter(ajusteb_BV, ajusteb_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 4.75Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
infile8 = "/content/bvr_008_5000Myr.dat"

file8 = open(infile8, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file8:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file8.close()

# %%
#Comparando com Fis02013b
plt.scatter(bls_BV, bls_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajusteb_BV=[]
ajusteb_V=[]

EBV=0.26
mv_Mv=10

for i in range(len(bls_BV)):
  ajusteb_BV.append(bls_BV[i] - EBV)
for i in range(len(bls_V)):
  ajusteb_V.append(bls_V[i] - mv_Mv)

plt.scatter(ajusteb_BV, ajusteb_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
infile9 = "/content/bvr_008_5500Myr.dat"

file9 = open(infile9, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file9:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file9.close()

# %%
#Comparando com Fis02013b
plt.scatter(bls_BV, bls_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5.5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajusteb_BV=[]
ajusteb_V=[]

EBV=0.26
mv_Mv=10

for i in range(len(bls_BV)):
  ajusteb_BV.append(bls_BV[i] - EBV)
for i in range(len(bls_V)):
  ajusteb_V.append(bls_V[i] - mv_Mv)

plt.scatter(ajusteb_BV, ajusteb_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5.5Gyr" + "\n" + "Z=0.008")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
infile10 = "/content/bvr_001_5000Myr.dat"

file10 = open(infile10, "r")

iso_BV=[]
iso_V=[]
                        
for linha in file10:
  partes = linha.split()
  iso_BV.append(float(partes[4].strip()))
  iso_V.append(float(partes[2].strip()))

file9.close()

#Comparando com Fis02013b
plt.scatter(bls_BV, bls_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5Gyr" + "\n" + "Z=0.001")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()

# %%
#Ajustando
ajusteb_BV=[]
ajusteb_V=[]

EBV=0.45
mv_Mv=10

for i in range(len(bls_BV)):
  ajusteb_BV.append(bls_BV[i] - EBV)
for i in range(len(bls_V)):
  ajusteb_V.append(bls_V[i] - mv_Mv)

plt.scatter(ajusteb_BV, ajusteb_V, s=1, label="Fis02013b")
plt.scatter(iso_BV, iso_V, s=1, c="red", label="Isócrona: 5Gyr" + "\n" + "Z=0.001")
plt.gca().invert_yaxis()
plt.ylabel("$V_{mag}$")
plt.xlabel("B-V")
plt.legend()
plt.show()
